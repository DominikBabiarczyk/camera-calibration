# %% [markdown]
# ## transformata Censusa

# %%
# Out:
# Text(0.5, 1.0, 'dispL')

# %% [markdown]
# implementacja

# %%
def censusa(image_left, image_right, border=2):

    XX, YY = image_left.shape

    for x in range(border, XX - border):
        for y in range(border, YY - border):
            frame = image_left[x-border: x+border+1, y-border: y+border+1]
            print(frame)

censusa(cv2.cvtColor(aloeL, cv2.COLOR_BGR2GRAY), cv2.cvtColor(aloeR, cv2.COLOR_BGR2GRAY))
# Out:
# [[179 175 180 182 174]
#  [177 173 178 181 178]
#  [150 146 150 153 152]
#  [138 133 135 137 134]
#  [161 157 158 157 152]]
# [[175 180 182 174 172]
#  [173 178 181 178 180]
#  [146 150 153 152 157]
#  [133 135 137 134 137]
#  [157 158 157 152 152]]
# [[180 182 174 172 172]
#  [178 181 178 180 184]
#  [150 153 152 157 161]
#  [135 137 134 137 136]
#  [158 157 152 152 145]]
# [[182 174 172 172 168]
#  [181 178 180 184 180]
#  [153 152 157 161 157]
#  [137 134 137 136 126]
#  [157 152 152 145 128]]
# [[174 172 172 168 173]
#  [178 180 184 180 178]
#  [152 157 161 157 168]
#  [134 137 136 126 147]
#  [152 152 145 128 134]]
# [[172 172 168 173 163]
#  [180 184 180 178 175]
#  [157 161 157 168 180]
#  [137 136 126 147 177]
#  [152 145 128 134 177]]
# [[172 168 173 163 175]
#  [184 180 178 175 184]
#  [161 157 168 180 185]
#  [136 126 147 177 181]
#  [145 128 134 177 183]]
# [[168 173 163 175 165]
#  [180 178 175 184 182]
#  [157 168 180 185 192]
#  [126 147 177 181 190]
# ...
